# %%
# %matplotlib inline

# %%
import pandas as pd
from Bio import SeqIO, Entrez
Entrez.email = 'adam.hockenberry@utexas.edu'  # Always tell NCBI who you are
import time
import glob

# %% [markdown]
# # First make the starting datatable better

# %%
df = pd.read_csv('../Data/NCBI_phage_db/all_complete_phage_info.csv')
print(df.shape)
df.head()
# Out:
# (17345, 18)
#    Accession          Release_Date                       Species  \
# 0  NC_045425  2019-12-16T00:00:00Z             Thermus virus OH3
# 1  NC_044940  2019-10-02T00:00:00Z  Pectinobacterium virus PEAT2
# 2  NC_043767  2019-07-20T00:00:00Z     Mycobacterium virus TA17a
# 3  NC_043027  2019-06-28T00:00:00Z           Bacillus virus PBS1
# 4  NC_043028  2019-06-28T00:00:00Z       Xanthomonas virus Xf109
#
#            Genus        Family  Length Sequence_Type Nuc_Completeness  \
# 0            NaN    Inoviridae    5688        RefSeq         complete
# 1      Peatvirus    Myoviridae   48659        RefSeq         complete
# 2  Rosebushvirus  Siphoviridae   67324        RefSeq         complete
# 3            NaN    Myoviridae  252197        RefSeq         complete
# 4            NaN    Inoviridae    7190        RefSeq         complete
#
#   Genotype Segment                                            Authors  \
# 0      NaN     NaN  Nagayoshi,Y., Kumagae,K., Mori,K., Tashiro,K.,...
# 1      NaN     NaN     Kalischuk,M., Hachey,J., Thomas,D., Kawchuk,L.
# 2      NaN     NaN  Lunt,B.L., Payne,D.E., Fisher,J.N.B., Smith,K....
# 3      NaN     NaN  Russell,D.A., Jacobs-Sera,D., Duda,R., Hatfull...
# 4      NaN     NaN                                           Yeh,T.Y.
#
#   Publications    Geo_Location                                 Host  \
# 0     26941711           Japan             Thermus thermophilus HB8
# 1          NaN             NaN                                  NaN
# 2          NaN  USA: Provo, UT  Mycolicibacterium smegmatis MC2 155
# 3          NaN             NaN                    Bacillus subtilis
# 4     27743252             NaN        Xanthomonas oryzae ATCC 35933
#
#   Isolation_Source Collection_Date BioSample  \
# 0              NaN             NaN       NaN
# 1              NaN             NaN       NaN
# 2              NaN      2009-09-13       NaN
# 3              NaN             NaN       NaN
# 4              NaN             NaN       NaN
#
#                                        GenBank_Title
# 0  Thermus phage phiOH3 genomic DNA, complete genome
# 1        Pectobacterium phage PEAT2, complete genome
# 2         Mycobacterium virus TA17a, complete genome
# 3               Bacillus virus PBS1, complete genome
# 4           Xanthomonas phage Xf109, complete genome

# %%
df = df[df['Host'].isnull()==False]
print(df.shape)
# Out:
# (12483, 18)

# %%
df['Host'].value_counts()
# Out:
# Mycolicibacterium smegmatis MC2 155        1727
# Escherichia coli                            745
# Gordonia terrae                             382
# Escherichia coli C                          346
# Lactococcus lactis                          323
#                                            ...
# Streptococcus pseudoporcinus SPIN 20026       1
# Streptococcus pneumoniae GA41317              1
# Streptococcus uberis C5388                    1
# Escherichia coli PA8                          1
# Leptospira                                    1
# Name: Host, Length: 967, dtype: int64

# %% [markdown]
# **Better treatment of host taxonomy**

# %%
taxonomies_to_fetch = ['superkingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species']
problematic_hosts = []
for host in list(set(df['Host']))[:]:
    matching_indices = df[df['Host']==host].index
    if df.loc[matching_indices]['Host_superkingdom_id'].isnull().all()==False:
        print('Skipping')
        continue
    print(host)
    handle = Entrez.esearch(db='Taxonomy', term=host)
    record = Entrez.read(handle)
    if len(record['IdList']) != 1:
        problematic_hosts.append(host)
        continue
    record_id = record['IdList'][0]
    handle = Entrez.efetch(db="Taxonomy", id=record_id, retmode="xml")
    records = Entrez.read(handle)
    if len(records) != 1:
        problematic_hosts.append(host)
        continue        
    record = records[0]
    ###First get the genetic code right
    df.at[matching_indices, 'GeneticCode'] = record['GeneticCode']['GCId']
    ###Now possibly add the record itself
    if record ['Rank'] in taxonomies_to_fetch:
        df.at[matching_indices, 'Host_{}_id'.format(record['Rank'])] = record['TaxId']
        df.at[matching_indices, 'Host_{}_name'.format(record['Rank'])] = record['ScientificName']
    ###Finally go through the lineage
    lineage = record['LineageEx']
    for i in lineage:
        if i['Rank'] in taxonomies_to_fetch:
            df.at[matching_indices, 'Host_{}_id'.format(i['Rank'])] = i['TaxId']
            df.at[matching_indices, 'Host_{}_name'.format(i['Rank'])] = i['ScientificName']
    time.sleep(10)
# Out:
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Escherichia coli O157:H43 str. T22
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Escherichia coli O145:NM
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Nodularia
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Gordonia
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Escherichia coli O104:H4
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Escherichia coli BL21(DE3)
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Bacillus
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Escherichia coli O157:H7 str. EDL933
# Skipping
# [Bacillus] clarkii
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Yersinia enterocolitica (type O:3)
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Streptomyces coelicolor A3(2)
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Edwardsiella
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# [Brevibacterium] flavum
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Curvibacter sp. AEP1.3
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Streptococcus anginosus MAS624
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Morganella sp. (in: Bacteria)
# Skipping
# Skipping
# Skipping
# Skipping
# Clostridium saccharoperbutylacetonicum N1-4(HMT)
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Methylophilaceae bacterium IMCC19250
# Skipping
# Erwinia horticola
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Escherichia coli O157:H7
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Escherichia coli O111:H2
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Escherichia coli O103:H25 str. NIPH-11060424
# Skipping
# Skipping
# Skipping
# Skipping
# Escherichia coli DH5[alpha]
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Bacillus sp. (in: Bacteria)
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping
# Vibrio maritimus
# Vibrio campbellii ATCC BAA-1116
# Flavobacterium sp. LMO6
# Streptococcus
# Geobacillus stearothermophilus
# Streptococcus suis TL13
# Brucella abortus 544
# Corynebacterium glutamicum
# Staphylococcus hominis
# Streptococcus infantarius
# Aeromonas media
# Rheinheimera sp. BAL341
# Escherichia coli PA2
# Streptococcus henryi DSM 19005
# Cronobacter sakazakii
# Streptomyces azureus
# Streptococcus agalactiae ILRI005
# Burkholderia cepacia
# Streptococcus agalactiae GD201008-001
# Sinorhizobium meliloti 1021
# Pseudoalteromonas hodoensis
# Vibrio coralliilyticus
# Escherichia sp. MOD1-EC6098
# Ochrobactrum sp. POC9
# Streptococcus thermophilus ND03
# Lysinibacillus sphaericus C3-41
# Thermus sp. TC4
# Lactococcus garvieae Lg2
# Pseudomonas syringae
# Morganella morganii
# Microcystis aeruginosa
# Enterococcus faecalis 62
# Synechococcus sp. WH 8018
# Fusobacterium nucleatum
# Streptococcus intermedius
# Vibrio cholerae O1
# Streptococcus anginosus
# Sphaerotilus natans
# Idiomarinaceae bacterium N2-2
# Vibrio metschnikovii
# Streptococcus pneumoniae BS458
# Acaryochloris marina
# Rhizobium gallicum
# Acinetobacter baumannii A118
# Streptomyces toxytricini
# Sodalis glossinidius
# Mycolicibacterium aichiense
# Escherichia coli C
# Streptococcus pneumoniae ST556
# Lactococcus lactis subsp. cremoris TIFN7
# Streptococcus pneumoniae GA47033
# Bacteroides intestinalis
# Polaribacter
# Streptomyces sp.
# Lactobacillus
# Epibacterium mobile
# Microbacterium natoriense
# Caulobacter vibrioides CB15
# Streptococcus equinus
# Trichormus variabilis
# Plesiomonas sp.
# Streptococcus parauberis KCTC 11980BP
# Streptococcus suis ST1
# Aeromonas rivipollensis
# Pseudomonas aeruginosa CHA
# Myxococcus xanthus
# Sphingomonas paucimobilis
# Escherichia coli H8
# Clostridioides difficile
# Parabacteroides merdae
# Streptococcus pneumoniae GA41538
# Thermobifida fusca
# Gordonia alkanivorans
# Prochlorococcus marinus
# Streptococcus gordonii
# Yersinia
# Marinomonas sp.
# Sphingobium sp. IP1
# Halomonas ventosae
# Mycobacteroides abscessus subsp. bolletii F1725
# Escherichia coli J53
# Streptococcus parauberis KRS-02083
# Nonlabens
# Streptococcus mitis SK564
# Tsukamurella paurometabola
# Shigella dysenteriae
# Streptococcus suis YB51
# Enterococcus
# Cellulophaga baltica NN016038
# Streptomyces virginiae
# Streptomyces avermitilis
# Dinoroseobacter shibae
# Campylobacter jejuni subsp. jejuni
# Streptococcus agalactiae BSU450
# Phormidium sp. MIS-PhA
# Parabacteroides distasonis
# Cronobacter
# Clostridium perfringens ATCC 13124
# Tenacibaculum geojense
# Staphylococcus aureus subsp. aureus N315
# Pseudomonas fluorescens group
# Burkholderia pseudomallei K96243
# Paracoccus marcusii
# Streptococcus suis 98HAH33
# Staphylococcus haemolyticus
# Lactococcus
# Pseudoalteromonas marina
# Brevundimonas subvibrioides ATCC 15264
# Erwinia pyrifoliae
# Alteromonas
# Salmonella enterica subsp. enterica serovar Typhimurium str. LT2
# Paracoccus sulfuroxidans
# Mesorhizobium loti
# Propionibacterium
# Erysipelothrix rhusiopathiae
# Aminobacter sp. MSH1
# Shewanella inventionis
# Rhodoferax sp. IMCC26218
# Rhodobacter
# Bacillus pumilus BL8
# Clostridium tetani
# Lactobacillus delbrueckii subsp. bulgaricus
# Salinibacter ruber
# Microbacterium foliorum
# Pseudomonas aeruginosa PA14
# Streptomyces tricolor
# Streptococcus anginosus F0211
# Synechococcus sp. WH 8102
# Stenotrophomonas sp.
# Haemophilus influenzae
# Streptococcus pyogenes NZ131
# Paracoccus
# Streptococcus pseudopneumoniae 5247
# Streptococcus pseudopneumoniae 22725
# Salmonella enterica subsp. enterica serovar Rissen
# Streptococcus uberis B190
# Vibrio sp.
# Salmonella enterica subsp. enterica serovar Saintpaul
# Streptococcus pneumoniae GA17328
# Streptococcus oralis ATCC 49296
# Oncorhynchus mykiss
# Shewanella fidelis
# Gordonia sp.
# Streptococcus agalactiae GB00640
# Lactobacillus plantarum
# Vibrio mediterranei
# Prochlorococcus marinus str. MIT 9313
# Pseudomonas chlororaphis
# Streptococcus hyovaginalis DSM 12219
# Synechococcus sp. WH 7803
# Streptococcus thermophilus 1F8CT
# Aeromonas salmonicida subsp. salmonicida
# Mycobacterium sp.
# Pectobacterium carotovorum
# Streptococcus parauberis KCTC 11537
# Photobacterium damselae
# Bacillus subtilis
# Bacillus thuringiensis serovar kurstaki
# Aggregatibacter actinomycetemcomitans D11S-1
# Bacillus amyloliquefaciens
# Acinetobacter johnsonii
# Candidatus Pelagibacter
# Streptococcus pneumoniae 23F
# Salinivibrio sp.
# Providencia sp.
# Streptococcus phocae subsp. salmonis
# Escherichia coli PA33
# Acholeplasma laidlawii
# Microbacterium nematophilum
# Achromobacter animicus
# Shigella
# Escherichia coli PA11

# %%
df['Host_species_name'].value_counts()
# Out:
# Mycolicibacterium smegmatis    1978
# Escherichia coli               1187
# Salmonella enterica             423
# Pseudomonas aeruginosa          400
# Gordonia terrae                 382
#                                ...
# Salipiger profundus               1
# Pseudomonas sp. 1-1-1b            1
# Rothia dentocariosa               1
# Phaeobacter inhibens              1
# Microcystis elabens               1
# Name: Host_species_name, Length: 549, dtype: int64

# %%
df['GeneticCode'].value_counts()
# Out:
# 11    12021
# 1       270
# 4        15
# Name: GeneticCode, dtype: int64

# %% [markdown]
# **Fix the problematic hosts**

# %%
print(len(set(problematic_hosts)))
problematic_hosts
# Out:
# 27
# ['Escherichia coli O157:H43 str. T22',
#  'Escherichia coli O145:NM',
#  'Nodularia',
#  'Gordonia',
#  'Escherichia coli O104:H4',
#  'Escherichia coli BL21(DE3)',
#  'Bacillus',
#  'Escherichia coli O157:H7 str. EDL933',
#  '[Bacillus] clarkii',
#  'Yersinia enterocolitica (type O:3)',
#  'Streptomyces coelicolor A3(2)',
#  'Edwardsiella',
#  '[Brevibacterium] flavum',
#  'Curvibacter sp. AEP1.3',
#  'Streptococcus anginosus MAS624',
#  'Morganella sp. (in: Bacteria)',
#  'Clostridium saccharoperbutylacetonicum N1-4(HMT)',
#  'Methylophilaceae bacterium IMCC19250',
#  'Erwinia horticola',
#  'Escherichia coli O157:H7',
#  'Escherichia coli O111:H2',
#  'Escherichia coli O103:H25 str. NIPH-11060424',
#  'Escherichia coli DH5[alpha]',
#  'Bacillus sp. (in: Bacteria)',
#  'Yersinia',
#  'Phormidium sp. MIS-PhA',
#  'Paracoccus']

# %% [markdown]
# **Cases with special characters**

# %%
still_problematic = []
for host in problematic_hosts:
    matching_indices = df[df['Host']==host].index
    host = host.replace(':', ' ')
    host = host.replace('[', '').replace(']', '')
    host = host.replace('(', ' ').replace(')', ' ')
    if df.loc[matching_indices]['Host_superkingdom_id'].isnull().all()==False:
        print('Skipping')
        continue
    print(host)
    handle = Entrez.esearch(db='Taxonomy', term=host)
    record = Entrez.read(handle)
    if len(record['IdList']) != 1:
        still_problematic.append(host)
        continue
    record_id = record['IdList'][0]
    handle = Entrez.efetch(db="Taxonomy", id=record_id, retmode="xml")
    records = Entrez.read(handle)
    if len(records) != 1:
        still_problematic.append(host)
        continue        
    record = records[0]
    ###First get the genetic code right
    df.at[matching_indices, 'GeneticCode'] = record['GeneticCode']['GCId']
    ###Now possibly add the record itself
    if record ['Rank'] in taxonomies_to_fetch:
        df.at[matching_indices, 'Host_{}_id'.format(record['Rank'])] = record['TaxId']
        df.at[matching_indices, 'Host_{}_name'.format(record['Rank'])] = record['ScientificName']
    ###Finally go through the lineage
    lineage = record['LineageEx']
    for i in lineage:
        if i['Rank'] in taxonomies_to_fetch:
            df.at[matching_indices, 'Host_{}_id'.format(i['Rank'])] = i['TaxId']
            df.at[matching_indices, 'Host_{}_name'.format(i['Rank'])] = i['ScientificName']
    time.sleep(10)
# Out:
# Escherichia coli O157 H43 str. T22
# Escherichia coli O145 NM
# Nodularia
# Gordonia
# Escherichia coli O104 H4
# Escherichia coli BL21 DE3
# Bacillus
# Escherichia coli O157 H7 str. EDL933
# Bacillus clarkii
# Yersinia enterocolitica  type O 3
# Streptomyces coelicolor A3 2
# Edwardsiella
# Brevibacterium flavum
# Curvibacter sp. AEP1.3
# Streptococcus anginosus MAS624
# Morganella sp.  in  Bacteria
# Clostridium saccharoperbutylacetonicum N1-4 HMT
# Methylophilaceae bacterium IMCC19250
# Erwinia horticola
# Escherichia coli O157 H7
# Escherichia coli O111 H2
# Escherichia coli O103 H25 str. NIPH-11060424
# Escherichia coli DH5alpha
# Bacillus sp.  in  Bacteria
# Yersinia
# Phormidium sp. MIS-PhA
# Paracoccus

# %%
print(len(set(still_problematic)))
still_problematic
# Out:
# 11
# ['Nodularia',
#  'Gordonia',
#  'Bacillus',
#  'Edwardsiella',
#  'Curvibacter sp. AEP1.3',
#  'Streptococcus anginosus MAS624',
#  'Methylophilaceae bacterium IMCC19250',
#  'Erwinia horticola',
#  'Yersinia',
#  'Phormidium sp. MIS-PhA',
#  'Paracoccus']

# %% [markdown]
# **Cases with annoying genuses**

# %%
really_problematic = []
for host in still_problematic:
    matching_indices = df[df['Host']==host].index
    host = host.replace(':', ' ')
    host = host.replace('[', '').replace(']', '')
    host = host.replace('(', ' ').replace(')', ' ')
    if df.loc[matching_indices]['Host_superkingdom_id'].isnull().all()==False:
        print('Skipping')
        continue
    print(host)
    handle = Entrez.esearch(db='Taxonomy', term=host)
    record = Entrez.read(handle)
    if len(record['IdList']) == 0:
        really_problematic.append(host)
        continue
    temp_ids = record['IdList']
    successful_ids = []
    for record_id in temp_ids:
        handle = Entrez.efetch(db="Taxonomy", id=record_id, retmode="xml")
        records = Entrez.read(handle)
        if len(records) != 1:
            really_problematic.append(host)
            continue        
        record = records[0]
        lineage = record['LineageEx']
        for i in lineage:
            if i['Rank']=='superkingdom' and i['ScientificName'] =='Bacteria':
                successful_ids.append(record_id)
    if len(successful_ids) == 1:
        record_id = successful_ids[0]
    else:
        really_problematic.append(host)
    
    handle = Entrez.efetch(db="Taxonomy", id=record_id, retmode="xml")
    records = Entrez.read(handle)
    if len(records) != 1:
        really_problematic.append(host)
        continue        
    record = records[0]
    ###First get the genetic code right
    df.at[matching_indices, 'GeneticCode'] = record['GeneticCode']['GCId']
    ###Now possibly add the record itself
    if record ['Rank'] in taxonomies_to_fetch:
        df.at[matching_indices, 'Host_{}_id'.format(record['Rank'])] = record['TaxId']
        df.at[matching_indices, 'Host_{}_name'.format(record['Rank'])] = record['ScientificName']
    ###Finally go through the lineage
    lineage = record['LineageEx']
    for i in lineage:
        if i['Rank'] in taxonomies_to_fetch:
            df.at[matching_indices, 'Host_{}_id'.format(i['Rank'])] = i['TaxId']
            df.at[matching_indices, 'Host_{}_name'.format(i['Rank'])] = i['ScientificName']
    time.sleep(5)
# Out:
# Nodularia
# Gordonia
# Bacillus
# Edwardsiella
# Curvibacter sp. AEP1.3
# Streptococcus anginosus MAS624
# Methylophilaceae bacterium IMCC19250
# Erwinia horticola
# Yersinia
# Phormidium sp. MIS-PhA
# Paracoccus

# %%
print(len(really_problematic))
print(really_problematic)
# Out:
# 5
# ['Curvibacter sp. AEP1.3', 'Streptococcus anginosus MAS624', 'Methylophilaceae bacterium IMCC19250', 'Erwinia horticola', 'Phormidium sp. MIS-PhA']

# %%
answers = [2685271, 1328, 2030816, 551, 1199]

# %%
taxonomies_to_fetch = ['superkingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species']
problematic_hosts = []
for host, answer in zip(really_problematic, answers):
    matching_indices = df[df['Host']==host].index
    if df.loc[matching_indices]['Host_superkingdom_id'].isnull().all()==False:
        print('Skipping')
        continue
    print(host)
    record_id = str(answer)
    handle = Entrez.efetch(db="Taxonomy", id=record_id, retmode="xml")
    records = Entrez.read(handle)    
    record = records[0]
    ###First get the genetic code right
    df.at[matching_indices, 'GeneticCode'] = record['GeneticCode']['GCId']
    ###Now possibly add the record itself
    if record ['Rank'] in taxonomies_to_fetch:
        df.at[matching_indices, 'Host_{}_id'.format(record['Rank'])] = record['TaxId']
        df.at[matching_indices, 'Host_{}_name'.format(record['Rank'])] = record['ScientificName']
    ###Finally go through the lineage
    lineage = record['LineageEx']
    for i in lineage:
        if i['Rank'] in taxonomies_to_fetch:
            df.at[matching_indices, 'Host_{}_id'.format(i['Rank'])] = i['TaxId']
            df.at[matching_indices, 'Host_{}_name'.format(i['Rank'])] = i['ScientificName']
    time.sleep(10)
# Out:
# Skipping
# Skipping
# Skipping
# Skipping
# Skipping

# %% [markdown]
# **Write the new and improved file**

# %%
df['Host_superkingdom_name'].value_counts()
# Out:
# Bacteria     12211
# Eukaryota      270
# Archaea          2
# Name: Host_superkingdom_name, dtype: int64

# %%
df = df[df['Host_superkingdom_name']=='Bacteria']
print(df.shape)
# Out:
# (12211, 33)

# %%
df.to_csv('../Data/NCBI_phage_db/all_complete_phage_info_HOSTTAXONOMY_05152020.tsv', sep='\t', index=False)

# %% [markdown]
# # Select the rows that I care about

# %%
df = pd.read_csv('../Data/NCBI_phage_db/all_complete_phage_info_HOSTTAXONOMY_05152020.tsv', sep='\t')
print(df.shape)
df.head()
# Out:
# (12211, 33)
#    Accession          Release_Date                      Species  \
# 0  NC_045425  2019-12-16T00:00:00Z            Thermus virus OH3
# 1  NC_043767  2019-07-20T00:00:00Z    Mycobacterium virus TA17a
# 2  NC_043027  2019-06-28T00:00:00Z          Bacillus virus PBS1
# 3  NC_043028  2019-06-28T00:00:00Z      Xanthomonas virus Xf109
# 4  NC_043029  2019-06-28T00:00:00Z  Stenotrophomonas virus SMA6
#
#            Genus        Family  Length Sequence_Type Nuc_Completeness  \
# 0            NaN    Inoviridae    5688        RefSeq         complete
# 1  Rosebushvirus  Siphoviridae   67324        RefSeq         complete
# 2            NaN    Myoviridae  252197        RefSeq         complete
# 3            NaN    Inoviridae    7190        RefSeq         complete
# 4            NaN    Inoviridae    7648        RefSeq         complete
#
#   Genotype Segment  ... Host_phylum_id     Host_phylum_name Host_class_id  \
# 0      NaN     NaN  ...         1297.0  Deinococcus-Thermus      188787.0
# 1      NaN     NaN  ...       201174.0       Actinobacteria        1760.0
# 2      NaN     NaN  ...         1239.0           Firmicutes       91061.0
# 3      NaN     NaN  ...         1224.0       Proteobacteria        1236.0
# 4      NaN     NaN  ...         1224.0       Proteobacteria        1236.0
#
#        Host_class_name Host_order_id    Host_order_name Host_family_id  \
# 0           Deinococci       68933.0          Thermales       188786.0
# 1       Actinobacteria       85007.0  Corynebacteriales         1762.0
# 2              Bacilli        1385.0         Bacillales       186817.0
# 3  Gammaproteobacteria      135614.0    Xanthomonadales        32033.0
# 4  Gammaproteobacteria      135614.0    Xanthomonadales        32033.0
#
#    Host_family_name  Host_species_id             Host_species_name
# 0        Thermaceae            274.0          Thermus thermophilus
# 1  Mycobacteriaceae           1772.0   Mycolicibacterium smegmatis
# 2       Bacillaceae           1423.0             Bacillus subtilis
# 3  Xanthomonadaceae            347.0            Xanthomonas oryzae
# 4  Xanthomonadaceae          40324.0  Stenotrophomonas maltophilia
#
# [5 rows x 33 columns]

# %%
df['Host_family_name'].value_counts()[:20]
# Out:
# Enterobacteriaceae      2453
# Mycobacteriaceae        2143
# Streptococcaceae        1446
# Pseudomonadaceae         617
# Gordoniaceae             452
# Synechococcaceae         386
# Bacillaceae              384
# Staphylococcaceae        351
# Vibrionaceae             326
# Micrococcaceae           304
# Streptomycetaceae        254
# Microbacteriaceae        253
# Propionibacteriaceae     211
# Moraxellaceae            182
# Flavobacteriaceae        181
# Lactobacillaceae         128
# Enterococcaceae          126
# Burkholderiaceae         122
# Pectobacteriaceae        105
# Erwiniaceae              105
# Name: Host_family_name, dtype: int64

# %%
selected_accession_numbers = ['NC_001604', 'NC_001416']
all_genomes = SeqIO.parse('../Data/NCBI_phage_db/all_complete_phage_nts.fasta', 'fasta')
for genome in all_genomes:
    if genome.id in selected_accession_numbers:
        with open('../Data/NCBI_phage_db/phage_genomes/{}.fasta'.format(genome.id), 'w') as outfile:
            SeqIO.write(genome, outfile, 'fasta')

# %% [markdown]
# # Split apart the combined genome `fasta` file to write the genomes that I selected

# %%
genome = SeqIO.read('../Data/NCBI_phage_db/phage_genomes/NC_001416.fasta', 'fasta')
# for genome_file in glob.glob('../Data/NCBI_phage_db/phage_genomes/*.fasta'):
#     genome = SeqIO.read(genome_file, 'fasta')

# %%
hits = []
all_cds = SeqIO.parse('../Data/NCBI_phage_db/all_complete_phage_CDS.fasta', 'fasta')
for cds in all_cds:
    if genome.id in cds.id.split(':')[0]:
        hits.append(cds)
print(len(hits))

# %%
print(len(hits))

# %%
for hit in hits:
    reverse_complement = False
    if 'join' in hit.id:
        continue
    if 'complement(' == hit.id[:11]:
        print('here')
        reverse_complement = True
#         hit.id = hit.id[11:-1]
    if len(hit.id.split(':')) == 2:
        region = hit.id.split(':')[-1]
        if len(region.split('..')) == 2:
            start = int(region.split('..')[0])
            stop = int(region.split('..')[-1])
    print(start, stop)
    print(genome.seq[start-1:stop]==hit.seq)

# %%
hit

# %%
hit

# %% [markdown]
# # Make CDS datatables for each of those genomes by merging the genome `fasta` file with the CDS `fasta` file

# %% [markdown]
# **et voila**
