# %%
# %matplotlib inline

# %%
import bacphlip
import glob
import pandas as pd
from collections import Counter

# %% [markdown]
# # Run BACPHLIP lifestyle predictions

# %%
full_df = pd.read_csv('../Data/NCBI_phage_db/paper_dataset_11_2020_with_clusters.tsv', sep='\t')
full_df.head()
# Out:
#    Accession SRA_Accession          Release_Date                   Species  \
# 0  NC_050154           NaN  2020-08-13T00:00:00Z      Escherichia phage D6
# 1  NC_050143           NaN  2020-08-10T00:00:00Z   Pseudomonas phage datas
# 2  NC_050144           NaN  2020-08-10T00:00:00Z   Pseudomonas phage Epa14
# 3  NC_050145           NaN  2020-08-10T00:00:00Z  Pseudomonas phage PaGU11
# 4  NC_050146           NaN  2020-08-10T00:00:00Z    Pseudomonas phage Epa7
#
#         Genus      Family  Length Sequence_Type Nuc_Completeness Genotype  \
# 0         NaN  Myoviridae   91159        RefSeq         complete      NaN
# 1  Pbunavirus  Myoviridae   60746        RefSeq         complete      NaN
# 2  Pbunavirus  Myoviridae   65797        RefSeq         complete      NaN
# 3  Pbunavirus  Myoviridae   65554        RefSeq         complete      NaN
# 4  Pbunavirus  Myoviridae   65629        RefSeq         complete      NaN
#
#    ...   Host_order_name Host_family_id    Host_family_name Host_genus_id  \
# 0  ...  Enterobacterales          543.0  Enterobacteriaceae         561.0
# 1  ...   Pseudomonadales       135621.0    Pseudomonadaceae         286.0
# 2  ...   Pseudomonadales       135621.0    Pseudomonadaceae         286.0
# 3  ...   Pseudomonadales       135621.0    Pseudomonadaceae         286.0
# 4  ...   Pseudomonadales       135621.0    Pseudomonadaceae         286.0
#
#   Host_genus_name arbitrary_cluster_id ranking_in_cluster  \
# 0     Escherichia                   35                  1
# 1     Pseudomonas                   17                 27
# 2     Pseudomonas                    6                  1
# 3     Pseudomonas                   17                 24
# 4     Pseudomonas                    5                  3
#
#   cluster_representative CDS_density CDS_number
# 0                    1.0    0.897366      118.0
# 1                    NaN         NaN        NaN
# 2                    1.0    0.908035       92.0
# 3                    NaN         NaN        NaN
# 4                    NaN         NaN        NaN
#
# [5 rows x 40 columns]

# %%
# host_species_list = [562]
host_species_list = list(set(full_df['Host_species_id']))
print(host_species_list)
# Out:
# [1280, 1665, 644, 2055, 1423, 104336, 1428, 666, 1307, 1308, 670, 287, 29471, 1313, 1314, 1311, 552, 1833, 1708203, 305, 562, 306, 76594, 1334, 1771959, 1464, 573, 317, 197, 1351, 1358, 1747, 470, 599, 36822, 996, 28901, 1639, 1772, 623, 1396, 1911]

# %% [markdown]
# **The folowing code block will take quite a while to run (perhaps a few hours) so be forewarned!**

# %%
phage_dir = '../Data/NCBI_phage_db/phage_genomes/'

for host_id in host_species_list:
    species_df = full_df[(full_df['Host_species_id']==host_id) & (full_df['cluster_representative']==1)]
    for index in species_df.index:
        virus_id = species_df.loc[index]['Accession']
        viral_fasta = phage_dir + '{}_phage_genomes/'.format(host_id) + '{}.fasta'.format(virus_id)
        print(viral_fasta)
        bacphlip.run_pipeline(viral_fasta)
# Out:
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_050154.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_050154.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_050154.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_050154.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_050154.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049941.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049941.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049941.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049941.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049941.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049942.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049942.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049942.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049942.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049942.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049924.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049924.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049924.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049924.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049924.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049926.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049926.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049926.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049926.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049926.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049813.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049813.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049813.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049813.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049813.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049814.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049814.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049814.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049814.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049814.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049822.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049822.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049822.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049822.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049822.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049832.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049832.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049832.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049832.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049832.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049427.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049427.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049427.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049427.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049427.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049457.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049457.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049457.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049457.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049457.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049466.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049466.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049466.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049466.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_049466.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048731.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048731.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048731.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048731.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048731.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048799.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048799.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048799.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048799.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048799.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047742.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047742.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047742.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047742.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047742.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047749.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047749.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047749.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047749.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047749.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047777.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047777.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047777.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047777.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047777.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047810.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047810.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047810.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047810.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047810.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047812.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047812.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047812.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047812.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047812.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047820.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047820.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047820.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047820.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047820.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047830.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047830.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047830.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047830.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047830.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047890.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047890.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047890.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047890.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047890.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047893.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047893.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047893.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047893.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047893.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047895.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047895.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047895.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047895.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047895.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047899.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047899.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047899.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047899.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047899.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047923.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047923.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047923.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047923.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047923.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047942.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047942.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047942.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047942.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047942.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047959.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047959.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047959.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047959.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047959.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047960.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047960.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047960.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047960.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047960.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047984.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047984.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047984.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047984.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047984.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047996.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047996.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047996.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047996.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_047996.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048002.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048002.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048002.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048002.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048002.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048023.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048023.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048023.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048023.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048023.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048063.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048063.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048063.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048063.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048063.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048064.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048064.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048064.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048064.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048064.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048073.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048073.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048073.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048073.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048073.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048079.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048079.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048079.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048079.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048079.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048082.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048082.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048082.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048082.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048082.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048112.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048112.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048112.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048112.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048112.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048136.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048136.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048136.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048136.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048136.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048163.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048163.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048163.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048163.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048163.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048170.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048170.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048170.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048170.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048170.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048172.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048172.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048172.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048172.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048172.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048177.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048177.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048177.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048177.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048177.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048178.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048178.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048178.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048178.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048178.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048186.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048186.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048186.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048186.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048186.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048193.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048193.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048193.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048193.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048193.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048195.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048195.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048195.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048195.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048195.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048196.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048196.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048196.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048196.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048196.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048208.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048208.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048208.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048208.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_048208.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041873.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041873.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041873.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041873.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041873.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041874.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041874.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041874.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041874.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041874.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041898.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041898.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041898.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041898.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041898.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041906.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041906.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041906.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041906.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041906.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041979.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041979.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041979.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041979.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041979.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041990.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041990.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041990.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041990.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_041990.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_042043.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_042043.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_042043.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_042043.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_042043.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_042046.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_042046.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_042046.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/562_phage_genomes/NC_042046.fasta.hmmsearch.tsv
# ...
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/NC_031078.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/NC_031078.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/NC_031078.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/NC_031078.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/NC_031078.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/NC_028818.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/NC_028818.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/NC_028818.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/NC_028818.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/NC_028818.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/NC_028974.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/NC_028974.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/NC_028974.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/NC_028974.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/NC_028974.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MT952852.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MT952852.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MT952852.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MT952852.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MT952852.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN444876.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN444876.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN444876.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN444876.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN444876.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN234192.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN234192.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN234192.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN234192.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN234192.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN204492.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN204492.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN204492.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN204492.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN204492.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN096379.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN096379.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN096379.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN096379.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MN096379.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MK305891.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MK305891.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MK305891.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MK305891.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MK305891.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MK433269.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MK433269.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MK433269.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MK433269.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MK433269.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MK450426.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MK450426.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MK450426.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MK450426.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MK450426.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH229862.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH229862.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH229862.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH229862.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH229862.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH229864.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH229864.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH229864.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH229864.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH229864.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH229865.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH229865.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH229865.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH229865.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH229865.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH171094.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH171094.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH171094.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH171094.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH171094.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH019216.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH019216.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH019216.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH019216.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MH019216.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MF975638.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MF975638.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MF975638.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MF975638.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MF975638.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MF358541.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MF358541.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MF358541.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MF358541.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/MF358541.fasta.bacphlip
# #################################################################################
# ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/KU530220.fasta
# #################################################################################
# Beginning BACPHLIP pipeline
# Finished six frame translation of genome (nucleotide) with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/KU530220.fasta.6frame
# Finished outside call to hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/KU530220.fasta.hmmsearch
# Finished converting hmmsearch with output stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/KU530220.fasta.hmmsearch.tsv
# Finished with BACPHLIP predictions! Final output file stored in ../Data/NCBI_phage_db/phage_genomes/1911_phage_genomes/KU530220.fasta.bacphlip
# #################################################################################

# %% [markdown]
# # Compile data into a dataframe

# %%
full_listy = []
for host_id in host_species_list:
    species_df = full_df[(full_df['Host_species_id']==host_id) & (full_df['cluster_representative']==1)]
    for index in species_df.index:
        virus_id = species_df.loc[index]['Accession']
        bacphlip_file = phage_dir + '{}_phage_genomes/'.format(host_id) + '{}.fasta.bacphlip'.format(virus_id)
        temp_df = pd.read_csv(bacphlip_file, '\t')
        prob_diff = abs(temp_df.loc[0]['Virulent']-temp_df.loc[0]['Temperate'])
        lifestyle = ''
        if temp_df.loc[0]['Virulent']>temp_df.loc[0]['Temperate']:
            lifestyle = 'Virulent'
        else:
            lifestyle = 'Temperate'
        full_listy.append((host_id, virus_id, lifestyle, prob_diff))

# %%
df = pd.DataFrame(full_listy, columns=['host_id', 'phage_id', 'phage_lifestyle', 'lifestyle_probability_difference'])
df.head()
# Out:
#    host_id   phage_id phage_lifestyle  lifestyle_probability_difference
# 0     1280  NC_048635       Temperate                          1.000000
# 1     1280  NC_048644       Temperate                          1.000000
# 2     1280  NC_047724        Virulent                          0.650000
# 3     1280  NC_047788        Virulent                          0.925000
# 4     1280  NC_047855        Virulent                          0.986177

# %%
df.to_csv('../Data/lifestyle_results_BACPHLIP.tsv', sep='\t', index=False)

# %% [markdown]
# **View aggregate results/stats**

# %%
df[df['lifestyle_probability_difference']>=0.7]['phage_lifestyle'].value_counts()
# Out:
# Virulent     921
# Temperate    824
# Name: phage_lifestyle, dtype: int64

# %%
full_listy = []
for host_id in host_species_list:
    print(host_id)
#     print(df[df['host_id']==host_id]['phage_lifestyle'].value_counts())
    print(df[(df['host_id']==host_id)].shape,
          df[(df['host_id']==host_id) & (df['lifestyle_probability_difference']>=0.95)].shape)
# Out:
# 1280
# (56, 4) (34, 4)
# 1665
# (49, 4) (12, 4)
# 644
# (30, 4) (9, 4)
# 2055
# (153, 4) (83, 4)
# 1423
# (24, 4) (5, 4)
# 104336
# (70, 4) (13, 4)
# 1428
# (39, 4) (11, 4)
# 666
# (20, 4) (8, 4)
# 1307
# (47, 4) (31, 4)
# 1308
# (55, 4) (12, 4)
# 670
# (28, 4) (11, 4)
# 287
# (79, 4) (25, 4)
# 29471
# (6, 4) (4, 4)
# 1313
# (43, 4) (36, 4)
# 1314
# (36, 4) (28, 4)
# 1311
# (26, 4) (21, 4)
# 552
# (31, 4) (13, 4)
# 1833
# (11, 4) (3, 4)
# 1708203
# (1, 4) (0, 4)
# 305
# (29, 4) (10, 4)
# 562
# (254, 4) (143, 4)
# 306
# (19, 4) (4, 4)
# 76594
# (18, 4) (5, 4)
# 1334
# (33, 4) (27, 4)
# 1771959
# (49, 4) (20, 4)
# 1464
# (11, 4) (6, 4)
# 573
# (130, 4) (76, 4)
# 317
# (33, 4) (10, 4)
# 197
# (4, 4) (1, 4)
# 1351
# (43, 4) (6, 4)
# 1358
# (117, 4) (46, 4)
# 1747
# (61, 4) (2, 4)
# 470
# (48, 4) (11, 4)
# 599
# (19, 4) (10, 4)
# 36822
# (22, 4) (5, 4)
# 996
# (2, 4) (0, 4)
# 28901
# (122, 4) (78, 4)
# 1639
# (14, 4) (12, 4)
# 1772
# (253, 4) (188, 4)
# 623
# (25, 4) (20, 4)
# 1396
# (41, 4) (14, 4)
# 1911
# (34, 4) (5, 4)
