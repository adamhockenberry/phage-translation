# %%
# %matplotlib inline

# %%
import pandas as pd
import glob
import subprocess

# %%
def call_RNAfold(sequence):
    sequence = sequence.replace('T', 'U')
    MyOut = subprocess.Popen(['RNAfold', '-p', '--noPS', '--constraint'],
            stdin=subprocess.PIPE,
            stdout=subprocess.PIPE, 
            stderr=subprocess.STDOUT)
    stdout, stderr = MyOut.communicate(input=str.encode(sequence))
    return stdout

def get_energy_RNAfold(stdout_string):
    temp = stdout_string.decode("utf-8") 
    energy_line = temp.split('\n')[-5]
    energy_val = energy_line[energy_line.index(' '):]
    energy_val = energy_val.strip().strip('()').strip()
    
    mfe_line = temp.split('\n')[-4]
    mfe_val = mfe_line[energy_line.index(' '):]
    mfe_val = mfe_val.strip().strip('[]').strip()
    return float(energy_val), float(mfe_val)

# %%
for host_tsv_file in glob.glob('../Data/host_genomes/' + '*.clean.tsv'):
#     if '562.clean.tsv' not in host_tsv_file:
#         continue
    print(host_tsv_file)
    df = pd.read_csv(host_tsv_file, sep = "\t", index_col = 0)
    for index in df.index[:]:
        us_seq = df.at[index, 'upstream_sequence'] 
        cds_seq = df.at[index, 'coding_sequence']
        beg_cds_seq = cds_seq[:30]
        if len(us_seq) == 30 and len(beg_cds_seq) == 30:
            rna_out = call_RNAfold(us_seq+beg_cds_seq)
            e1, e2 = get_energy_RNAfold(rna_out)
            df.at[index, 'secondary_structure'] = e2
            
        if len(cds_seq) > 90:
            int_cds_seq = cds_seq[30:90]
            rna_out = call_RNAfold(int_cds_seq)
            e1, e2 = get_energy_RNAfold(rna_out)
            df.at[index, 'secondary_structure_internal'] = e2
    
    df.to_csv(host_tsv_file, sep = "\t")
# Out:
# ../Data/host_genomes/357276.clean.tsv
# ../Data/host_genomes/1280.clean.tsv
# ../Data/host_genomes/28450.clean.tsv
# ../Data/host_genomes/562.clean.tsv
# ../Data/host_genomes/435591.clean.tsv
# ../Data/host_genomes/717959.clean.tsv
# ../Data/host_genomes/1590.clean.tsv
# ../Data/host_genomes/470.clean.tsv
# ../Data/host_genomes/1314.clean.tsv
# ../Data/host_genomes/1639.clean.tsv
# ../Data/host_genomes/90371.clean.tsv
# ../Data/host_genomes/305.clean.tsv
# ../Data/host_genomes/36809.clean.tsv
# ../Data/host_genomes/573.clean.tsv
# ../Data/host_genomes/657318.clean.tsv
# ../Data/host_genomes/287.clean.tsv
# ../Data/host_genomes/1428.clean.tsv

# %%
for virus_folder in glob.glob('../Data/*_rep_viruses/'):
#     if '562_rep_viruses' not in virus_folder:
#         continue
    print('###', virus_folder)
    for virus_tsv_file in glob.glob(virus_folder + '*.clean.tsv'):
        print(virus_tsv_file)
        ###
        df = pd.read_csv(virus_tsv_file, sep = "\t", index_col = 0)
        for index in df.index[:]:
            us_seq = df.at[index, 'upstream_sequence'] 
            cds_seq = df.at[index, 'coding_sequence']
            beg_cds_seq = cds_seq[:30]
            if len(us_seq) == 30 and len(beg_cds_seq) == 30:
                rna_out = call_RNAfold(us_seq+beg_cds_seq)
                e1, e2 = get_energy_RNAfold(rna_out)
                df.at[index, 'secondary_structure'] = e2
            if len(cds_seq) > 90:
                int_cds_seq = cds_seq[30:90]
                rna_out = call_RNAfold(int_cds_seq)
                e1, e2 = get_energy_RNAfold(rna_out)
                df.at[index, 'secondary_structure_internal'] = e2
        df.to_csv(virus_tsv_file, sep = "\t")
# Out:
# ### ../Data/1314_rep_viruses/
# ../Data/1314_rep_viruses/7591.clean.tsv
# ../Data/1314_rep_viruses/5035.clean.tsv
# ../Data/1314_rep_viruses/3755.clean.tsv
# ../Data/1314_rep_viruses/8429.clean.tsv
# ../Data/1314_rep_viruses/1022.clean.tsv
# ../Data/1314_rep_viruses/15413.clean.tsv
# ../Data/1314_rep_viruses/3568.clean.tsv
# ../Data/1314_rep_viruses/6579.clean.tsv
# ../Data/1314_rep_viruses/6777.clean.tsv
# ../Data/1314_rep_viruses/10921.clean.tsv
# ../Data/1314_rep_viruses/1738.clean.tsv
# ../Data/1314_rep_viruses/4398.clean.tsv
# ../Data/1314_rep_viruses/15421.clean.tsv
# ../Data/1314_rep_viruses/657.clean.tsv
# ../Data/1314_rep_viruses/6112.clean.tsv
# ../Data/1314_rep_viruses/11570.clean.tsv
# ../Data/1314_rep_viruses/4185.clean.tsv
# ../Data/1314_rep_viruses/14360.clean.tsv
# ../Data/1314_rep_viruses/10417.clean.tsv
# ../Data/1314_rep_viruses/11520.clean.tsv
# ../Data/1314_rep_viruses/3015.clean.tsv
# ../Data/1314_rep_viruses/5342.clean.tsv
# ../Data/1314_rep_viruses/7759.clean.tsv
# ../Data/1314_rep_viruses/6488.clean.tsv
# ../Data/1314_rep_viruses/4578.clean.tsv
# ../Data/1314_rep_viruses/13644.clean.tsv
# ../Data/1314_rep_viruses/8652.clean.tsv
# ../Data/1314_rep_viruses/10603.clean.tsv
# ../Data/1314_rep_viruses/6321.clean.tsv
# ../Data/1314_rep_viruses/628.clean.tsv
# ../Data/1314_rep_viruses/5996.clean.tsv
# ../Data/1314_rep_viruses/7394.clean.tsv
# ../Data/1314_rep_viruses/6716.clean.tsv
# ../Data/1314_rep_viruses/3899.clean.tsv
# ../Data/1314_rep_viruses/4421.clean.tsv
# ../Data/1314_rep_viruses/2142.clean.tsv
# ../Data/1314_rep_viruses/2597.clean.tsv
# ../Data/1314_rep_viruses/3517.clean.tsv
# ../Data/1314_rep_viruses/6173.clean.tsv
# ../Data/1314_rep_viruses/5646.clean.tsv
# ../Data/1314_rep_viruses/9412.clean.tsv
# ../Data/1314_rep_viruses/17895.clean.tsv
# ../Data/1314_rep_viruses/10794.clean.tsv
# ### ../Data/36809_rep_viruses/
# ../Data/36809_rep_viruses/7585.clean.tsv
# ../Data/36809_rep_viruses/1583.clean.tsv
# ../Data/36809_rep_viruses/4431.clean.tsv
# ../Data/36809_rep_viruses/6134.clean.tsv
# ../Data/36809_rep_viruses/3784.clean.tsv
# ../Data/36809_rep_viruses/2039.clean.tsv
# ../Data/36809_rep_viruses/1305.clean.tsv
# ../Data/36809_rep_viruses/3803.clean.tsv
# ../Data/36809_rep_viruses/1975.clean.tsv
# ../Data/36809_rep_viruses/10630.clean.tsv
# ../Data/36809_rep_viruses/895.clean.tsv
# ../Data/36809_rep_viruses/17090.clean.tsv
# ../Data/36809_rep_viruses/3243.clean.tsv
# ../Data/36809_rep_viruses/8553.clean.tsv
# ../Data/36809_rep_viruses/3353.clean.tsv
# ../Data/36809_rep_viruses/5967.clean.tsv
# ../Data/36809_rep_viruses/3503.clean.tsv
# ../Data/36809_rep_viruses/9745.clean.tsv
# ../Data/36809_rep_viruses/6301.clean.tsv
# ../Data/36809_rep_viruses/2378.clean.tsv
# ../Data/36809_rep_viruses/4286.clean.tsv
# ### ../Data/28450_rep_viruses/
# ../Data/28450_rep_viruses/9350.clean.tsv
# ../Data/28450_rep_viruses/13541.clean.tsv
# ../Data/28450_rep_viruses/1346.clean.tsv
# ../Data/28450_rep_viruses/6955.clean.tsv
# ../Data/28450_rep_viruses/8179.clean.tsv
# ../Data/28450_rep_viruses/8759.clean.tsv
# ../Data/28450_rep_viruses/9569.clean.tsv
# ../Data/28450_rep_viruses/9018.clean.tsv
# ../Data/28450_rep_viruses/18168.clean.tsv
# ../Data/28450_rep_viruses/4056.clean.tsv
# ../Data/28450_rep_viruses/3489.clean.tsv
# ../Data/28450_rep_viruses/18990.clean.tsv
# ../Data/28450_rep_viruses/9314.clean.tsv
# ../Data/28450_rep_viruses/9969.clean.tsv
# ../Data/28450_rep_viruses/9831.clean.tsv
# ../Data/28450_rep_viruses/9634.clean.tsv
# ../Data/28450_rep_viruses/8452.clean.tsv
# ../Data/28450_rep_viruses/8413.clean.tsv
# ../Data/28450_rep_viruses/3819.clean.tsv
# ../Data/28450_rep_viruses/9361.clean.tsv
# ../Data/28450_rep_viruses/8974.clean.tsv
# ../Data/28450_rep_viruses/10510.clean.tsv
# ../Data/28450_rep_viruses/4961.clean.tsv
# ../Data/28450_rep_viruses/9187.clean.tsv
# ../Data/28450_rep_viruses/2524.clean.tsv
# ../Data/28450_rep_viruses/8433.clean.tsv
# ../Data/28450_rep_viruses/2684.clean.tsv
# ../Data/28450_rep_viruses/9769.clean.tsv
# ../Data/28450_rep_viruses/1351.clean.tsv
# ../Data/28450_rep_viruses/8114.clean.tsv
# ../Data/28450_rep_viruses/9213.clean.tsv
# ../Data/28450_rep_viruses/8165.clean.tsv
# ../Data/28450_rep_viruses/7687.clean.tsv
# ### ../Data/562_rep_viruses/
# ../Data/562_rep_viruses/6088.clean.tsv
# ../Data/562_rep_viruses/6277.clean.tsv
# ../Data/562_rep_viruses/2454.clean.tsv
# ../Data/562_rep_viruses/3758.clean.tsv
# ../Data/562_rep_viruses/6382.clean.tsv
# ../Data/562_rep_viruses/197.clean.tsv
# ../Data/562_rep_viruses/2797.clean.tsv
# ../Data/562_rep_viruses/710.clean.tsv
# ../Data/562_rep_viruses/3861.clean.tsv
# ../Data/562_rep_viruses/2440.clean.tsv
# ../Data/562_rep_viruses/12799.clean.tsv
# ../Data/562_rep_viruses/4785.clean.tsv
# ../Data/562_rep_viruses/2928.clean.tsv
# ../Data/562_rep_viruses/4509.clean.tsv
# ../Data/562_rep_viruses/3329.clean.tsv
# ../Data/562_rep_viruses/3868.clean.tsv
# ../Data/562_rep_viruses/604.clean.tsv
# ../Data/562_rep_viruses/5142.clean.tsv
# ../Data/562_rep_viruses/8689.clean.tsv
# ../Data/562_rep_viruses/1858.clean.tsv
# ../Data/562_rep_viruses/176.clean.tsv
# ../Data/562_rep_viruses/206.clean.tsv
# ../Data/562_rep_viruses/2892.clean.tsv
# ../Data/562_rep_viruses/4546.clean.tsv
# ../Data/562_rep_viruses/2530.clean.tsv
# ../Data/562_rep_viruses/937.clean.tsv
# ../Data/562_rep_viruses/8248.clean.tsv
# ../Data/562_rep_viruses/11286.clean.tsv
# ../Data/562_rep_viruses/2898.clean.tsv
# ../Data/562_rep_viruses/1255.clean.tsv
# ../Data/562_rep_viruses/504.clean.tsv
# ../Data/562_rep_viruses/2242.clean.tsv
# ../Data/562_rep_viruses/4591.clean.tsv
# ../Data/562_rep_viruses/6594.clean.tsv
# ../Data/562_rep_viruses/16198.clean.tsv
# ../Data/562_rep_viruses/15708.clean.tsv
# ../Data/562_rep_viruses/2462.clean.tsv
# ../Data/562_rep_viruses/4390.clean.tsv
# ../Data/562_rep_viruses/2749.clean.tsv
# ../Data/562_rep_viruses/2396.clean.tsv
# ../Data/562_rep_viruses/5749.clean.tsv
# ../Data/562_rep_viruses/6274.clean.tsv
# ../Data/562_rep_viruses/5727.clean.tsv
# ../Data/562_rep_viruses/2936.clean.tsv
# ../Data/562_rep_viruses/4517.clean.tsv
# ../Data/562_rep_viruses/688.clean.tsv
# ../Data/562_rep_viruses/3271.clean.tsv
# ../Data/562_rep_viruses/4777.clean.tsv
# ../Data/562_rep_viruses/3682.clean.tsv
# ../Data/562_rep_viruses/4407.clean.tsv
# ../Data/562_rep_viruses/2017.clean.tsv
# ../Data/562_rep_viruses/1128.clean.tsv
# ../Data/562_rep_viruses/2881.clean.tsv
# ../Data/562_rep_viruses/15255.clean.tsv
# ../Data/562_rep_viruses/509.clean.tsv
# ../Data/562_rep_viruses/16060.clean.tsv
# ../Data/562_rep_viruses/10857.clean.tsv
# ../Data/562_rep_viruses/5553.clean.tsv
# ../Data/562_rep_viruses/9899.clean.tsv
# ../Data/562_rep_viruses/2690.clean.tsv
# ../Data/562_rep_viruses/2832.clean.tsv
# ../Data/562_rep_viruses/3143.clean.tsv
# ../Data/562_rep_viruses/12873.clean.tsv
# ../Data/562_rep_viruses/5328.clean.tsv
# ../Data/562_rep_viruses/5434.clean.tsv
# ../Data/562_rep_viruses/622.clean.tsv
# ../Data/562_rep_viruses/14178.clean.tsv
# ../Data/562_rep_viruses/8046.clean.tsv
# ../Data/562_rep_viruses/849.clean.tsv
# ../Data/562_rep_viruses/3340.clean.tsv
# ../Data/562_rep_viruses/3030.clean.tsv
# ../Data/562_rep_viruses/12110.clean.tsv
# ../Data/562_rep_viruses/7049.clean.tsv
# ../Data/1639_rep_viruses/1371.clean.tsv
# ../Data/1639_rep_viruses/420.clean.tsv
# ../Data/1639_rep_viruses/1479.clean.tsv
# ../Data/1639_rep_viruses/6545.clean.tsv
# ../Data/1639_rep_viruses/1344.clean.tsv
# ../Data/1639_rep_viruses/9661.clean.tsv
# ../Data/1639_rep_viruses/8983.clean.tsv
# ../Data/1639_rep_viruses/5303.clean.tsv
# ../Data/1639_rep_viruses/6497.clean.tsv
# ../Data/1639_rep_viruses/8169.clean.tsv
# ../Data/1639_rep_viruses/6612.clean.tsv
# ../Data/1639_rep_viruses/6063.clean.tsv
# ../Data/1639_rep_viruses/1475.clean.tsv
# ../Data/1639_rep_viruses/383.clean.tsv
# ../Data/1639_rep_viruses/397.clean.tsv
# ../Data/1639_rep_viruses/3249.clean.tsv
# ../Data/1639_rep_viruses/3972.clean.tsv
# ../Data/1639_rep_viruses/14875.clean.tsv
# ../Data/1639_rep_viruses/8450.clean.tsv
# ../Data/1639_rep_viruses/2271.clean.tsv
# ../Data/1639_rep_viruses/5451.clean.tsv
# ../Data/1639_rep_viruses/6452.clean.tsv
# ../Data/1639_rep_viruses/8287.clean.tsv
# ../Data/1639_rep_viruses/3214.clean.tsv
# ../Data/1639_rep_viruses/5024.clean.tsv
# ../Data/1639_rep_viruses/8239.clean.tsv
# ../Data/1639_rep_viruses/5719.clean.tsv
# ### ../Data/657318_rep_viruses/
# ../Data/657318_rep_viruses/10410.clean.tsv
# ../Data/657318_rep_viruses/15169.clean.tsv
# ../Data/657318_rep_viruses/12749.clean.tsv
# ../Data/657318_rep_viruses/11274.clean.tsv
# ../Data/657318_rep_viruses/13839.clean.tsv
# ../Data/657318_rep_viruses/10634.clean.tsv
# ../Data/657318_rep_viruses/1839.clean.tsv
# ../Data/657318_rep_viruses/7712.clean.tsv
# ../Data/657318_rep_viruses/17772.clean.tsv
# ../Data/657318_rep_viruses/5535.clean.tsv
# ../Data/657318_rep_viruses/17831.clean.tsv
# ../Data/657318_rep_viruses/8020.clean.tsv
# ../Data/657318_rep_viruses/11878.clean.tsv
# ../Data/657318_rep_viruses/18923.clean.tsv
# ../Data/657318_rep_viruses/17255.clean.tsv
# ../Data/657318_rep_viruses/15905.clean.tsv
# ../Data/657318_rep_viruses/15072.clean.tsv
# ../Data/657318_rep_viruses/13505.clean.tsv
# ../Data/657318_rep_viruses/11320.clean.tsv
# ../Data/657318_rep_viruses/17454.clean.tsv
# ../Data/657318_rep_viruses/15037.clean.tsv
# ../Data/657318_rep_viruses/17026.clean.tsv
# ../Data/657318_rep_viruses/13374.clean.tsv
# ../Data/657318_rep_viruses/10543.clean.tsv
# ../Data/657318_rep_viruses/8774.clean.tsv
# ../Data/657318_rep_viruses/11380.clean.tsv
# ../Data/657318_rep_viruses/5545.clean.tsv
# ../Data/657318_rep_viruses/18361.clean.tsv
# ../Data/657318_rep_viruses/12180.clean.tsv
# ../Data/657318_rep_viruses/11710.clean.tsv
# ../Data/657318_rep_viruses/19286.clean.tsv
# ../Data/657318_rep_viruses/9410.clean.tsv
# ../Data/657318_rep_viruses/15683.clean.tsv
# ../Data/657318_rep_viruses/11858.clean.tsv
# ../Data/657318_rep_viruses/11775.clean.tsv
# ../Data/657318_rep_viruses/10824.clean.tsv
# ../Data/657318_rep_viruses/17752.clean.tsv
# ../Data/657318_rep_viruses/7372.clean.tsv
# ../Data/657318_rep_viruses/11273.clean.tsv
# ../Data/657318_rep_viruses/2951.clean.tsv
# ../Data/657318_rep_viruses/14795.clean.tsv
# ../Data/657318_rep_viruses/1082.clean.tsv
# ../Data/657318_rep_viruses/17507.clean.tsv
# ../Data/657318_rep_viruses/11745.clean.tsv
# ../Data/657318_rep_viruses/6808.clean.tsv
# ../Data/657318_rep_viruses/11940.clean.tsv
# ../Data/657318_rep_viruses/12062.clean.tsv
# ../Data/657318_rep_viruses/12289.clean.tsv
# ../Data/657318_rep_viruses/17444.clean.tsv
# ../Data/657318_rep_viruses/12920.clean.tsv
# ../Data/657318_rep_viruses/16324.clean.tsv
# ../Data/657318_rep_viruses/5171.clean.tsv
# ../Data/657318_rep_viruses/14728.clean.tsv
# ../Data/657318_rep_viruses/1841.clean.tsv
# ../Data/657318_rep_viruses/18109.clean.tsv
# ../Data/657318_rep_viruses/13057.clean.tsv
# ../Data/657318_rep_viruses/18459.clean.tsv
# ../Data/657318_rep_viruses/10795.clean.tsv
# ../Data/657318_rep_viruses/15179.clean.tsv
# ../Data/657318_rep_viruses/13380.clean.tsv
# ../Data/657318_rep_viruses/10477.clean.tsv
# ../Data/657318_rep_viruses/3470.clean.tsv
# ../Data/657318_rep_viruses/15014.clean.tsv
# ../Data/657318_rep_viruses/16164.clean.tsv
# ../Data/657318_rep_viruses/989.clean.tsv
# ../Data/657318_rep_viruses/12527.clean.tsv
# ../Data/657318_rep_viruses/14500.clean.tsv
# ../Data/657318_rep_viruses/12094.clean.tsv
# ../Data/657318_rep_viruses/11604.clean.tsv
# ../Data/657318_rep_viruses/19408.clean.tsv
# ../Data/657318_rep_viruses/11227.clean.tsv
# ../Data/657318_rep_viruses/13687.clean.tsv
# ../Data/657318_rep_viruses/4988.clean.tsv
# ../Data/657318_rep_viruses/10712.clean.tsv
# ../Data/657318_rep_viruses/11905.clean.tsv
# ../Data/657318_rep_viruses/11134.clean.tsv
# ../Data/657318_rep_viruses/9317.clean.tsv
# ../Data/657318_rep_viruses/12968.clean.tsv
# ../Data/657318_rep_viruses/3286.clean.tsv
# ../Data/657318_rep_viruses/4529.clean.tsv
# ### ../Data/1280_rep_viruses/
# ../Data/1280_rep_viruses/1457.clean.tsv
# ../Data/1280_rep_viruses/5797.clean.tsv
# ../Data/1280_rep_viruses/4949.clean.tsv
# ../Data/1280_rep_viruses/5724.clean.tsv
# ../Data/1280_rep_viruses/6169.clean.tsv
# ../Data/1280_rep_viruses/4698.clean.tsv
# ../Data/1280_rep_viruses/6256.clean.tsv
# ../Data/1280_rep_viruses/1195.clean.tsv
# ../Data/1280_rep_viruses/5313.clean.tsv
# ../Data/1280_rep_viruses/5756.clean.tsv
# ../Data/1280_rep_viruses/2206.clean.tsv
# ../Data/1280_rep_viruses/7882.clean.tsv
# ../Data/1280_rep_viruses/1006.clean.tsv
# ../Data/1280_rep_viruses/10195.clean.tsv
# ../Data/1280_rep_viruses/5972.clean.tsv
# ../Data/1280_rep_viruses/7977.clean.tsv
# ../Data/1280_rep_viruses/5143.clean.tsv
# ../Data/1280_rep_viruses/16299.clean.tsv
# ### ../Data/1428_rep_viruses/
# ../Data/1428_rep_viruses/6917.clean.tsv
# ../Data/1428_rep_viruses/5549.clean.tsv
# ../Data/1428_rep_viruses/2437.clean.tsv
# ../Data/1428_rep_viruses/7696.clean.tsv
# ../Data/1428_rep_viruses/2071.clean.tsv
# ../Data/1428_rep_viruses/4580.clean.tsv
# ../Data/1428_rep_viruses/3512.clean.tsv
# ../Data/1428_rep_viruses/6792.clean.tsv
# ../Data/1428_rep_viruses/6625.clean.tsv
# ../Data/1428_rep_viruses/3977.clean.tsv
# ../Data/1428_rep_viruses/11521.clean.tsv
# ../Data/1428_rep_viruses/14780.clean.tsv
# ../Data/1428_rep_viruses/1448.clean.tsv
# ../Data/1428_rep_viruses/4392.clean.tsv
# ../Data/1428_rep_viruses/4874.clean.tsv
# ../Data/1428_rep_viruses/1937.clean.tsv
# ../Data/1428_rep_viruses/873.clean.tsv
# ../Data/1428_rep_viruses/6641.clean.tsv
# ../Data/1428_rep_viruses/1899.clean.tsv
# ../Data/1428_rep_viruses/9146.clean.tsv
# ../Data/1428_rep_viruses/7135.clean.tsv
# ../Data/1428_rep_viruses/2811.clean.tsv
# ../Data/1428_rep_viruses/4891.clean.tsv
# ../Data/1428_rep_viruses/4920.clean.tsv
# ../Data/1428_rep_viruses/4796.clean.tsv
# ../Data/1428_rep_viruses/3403.clean.tsv
# ../Data/1428_rep_viruses/2649.clean.tsv
# ../Data/1428_rep_viruses/3590.clean.tsv
# ../Data/1428_rep_viruses/3701.clean.tsv
# ../Data/1428_rep_viruses/1327.clean.tsv
# ../Data/1428_rep_viruses/8503.clean.tsv
# ../Data/1428_rep_viruses/1860.clean.tsv
# ../Data/1428_rep_viruses/9495.clean.tsv
# ../Data/1428_rep_viruses/1070.clean.tsv
# ../Data/1428_rep_viruses/2494.clean.tsv
# ../Data/1428_rep_viruses/7551.clean.tsv
# ../Data/1428_rep_viruses/2374.clean.tsv
# ../Data/1428_rep_viruses/5583.clean.tsv
# ../Data/1428_rep_viruses/74.clean.tsv
# ../Data/1428_rep_viruses/2659.clean.tsv
# ../Data/1428_rep_viruses/9937.clean.tsv
# ../Data/1428_rep_viruses/4219.clean.tsv
# ../Data/1428_rep_viruses/4675.clean.tsv
# ../Data/1428_rep_viruses/7274.clean.tsv
# ../Data/1428_rep_viruses/2498.clean.tsv
# ../Data/1428_rep_viruses/1722.clean.tsv
# ../Data/1428_rep_viruses/6968.clean.tsv
# ../Data/1428_rep_viruses/3530.clean.tsv
# ../Data/1428_rep_viruses/1950.clean.tsv
# ../Data/287_rep_viruses/3182.clean.tsv
# ../Data/287_rep_viruses/1378.clean.tsv
# ../Data/287_rep_viruses/1522.clean.tsv
# ../Data/287_rep_viruses/3527.clean.tsv
# ../Data/287_rep_viruses/1536.clean.tsv
# ../Data/287_rep_viruses/80.clean.tsv
# ../Data/287_rep_viruses/15738.clean.tsv
# ../Data/287_rep_viruses/4783.clean.tsv
# ../Data/287_rep_viruses/3921.clean.tsv
# ../Data/287_rep_viruses/2695.clean.tsv
# ../Data/287_rep_viruses/7623.clean.tsv
# ../Data/287_rep_viruses/4825.clean.tsv
# ../Data/287_rep_viruses/9300.clean.tsv
# ../Data/287_rep_viruses/5297.clean.tsv
# ../Data/287_rep_viruses/2362.clean.tsv
# ../Data/287_rep_viruses/6294.clean.tsv
# ../Data/287_rep_viruses/680.clean.tsv
# ../Data/287_rep_viruses/6030.clean.tsv
# ../Data/287_rep_viruses/7566.clean.tsv
# ../Data/287_rep_viruses/4351.clean.tsv
# ../Data/287_rep_viruses/5482.clean.tsv
# ../Data/287_rep_viruses/9753.clean.tsv
# ../Data/287_rep_viruses/1674.clean.tsv
# ../Data/287_rep_viruses/4321.clean.tsv
# ../Data/287_rep_viruses/1089.clean.tsv
# ../Data/287_rep_viruses/10356.clean.tsv
# ../Data/287_rep_viruses/6257.clean.tsv
# ../Data/287_rep_viruses/4855.clean.tsv
# ../Data/287_rep_viruses/2312.clean.tsv
# ../Data/287_rep_viruses/3070.clean.tsv
# ../Data/287_rep_viruses/2485.clean.tsv
# ../Data/287_rep_viruses/2034.clean.tsv
# ../Data/287_rep_viruses/5728.clean.tsv
# ../Data/287_rep_viruses/2962.clean.tsv
# ../Data/287_rep_viruses/3069.clean.tsv
# ../Data/287_rep_viruses/6961.clean.tsv
# ../Data/287_rep_viruses/10191.clean.tsv
# ../Data/287_rep_viruses/7142.clean.tsv
# ../Data/287_rep_viruses/14552.clean.tsv
# ../Data/287_rep_viruses/5314.clean.tsv
# ../Data/287_rep_viruses/3526.clean.tsv
# ../Data/287_rep_viruses/4526.clean.tsv
# ../Data/287_rep_viruses/6838.clean.tsv
# ../Data/287_rep_viruses/17034.clean.tsv
# ../Data/287_rep_viruses/10108.clean.tsv
# ../Data/287_rep_viruses/4261.clean.tsv
# ../Data/287_rep_viruses/6499.clean.tsv
# ../Data/287_rep_viruses/13215.clean.tsv
# ../Data/287_rep_viruses/8217.clean.tsv
# ../Data/287_rep_viruses/2759.clean.tsv
# ../Data/287_rep_viruses/8092.clean.tsv
# ../Data/287_rep_viruses/12433.clean.tsv
# ../Data/287_rep_viruses/32.clean.tsv
# ../Data/287_rep_viruses/3824.clean.tsv
# ../Data/287_rep_viruses/1010.clean.tsv
# ../Data/287_rep_viruses/6281.clean.tsv
# ../Data/287_rep_viruses/10018.clean.tsv
# ../Data/287_rep_viruses/1952.clean.tsv
# ../Data/287_rep_viruses/5817.clean.tsv
# ../Data/287_rep_viruses/9994.clean.tsv
# ../Data/287_rep_viruses/9500.clean.tsv
# ../Data/287_rep_viruses/3564.clean.tsv
# ../Data/287_rep_viruses/14822.clean.tsv
# ../Data/287_rep_viruses/1460.clean.tsv
# ../Data/287_rep_viruses/780.clean.tsv
# ../Data/287_rep_viruses/7888.clean.tsv
# ../Data/287_rep_viruses/2713.clean.tsv
# ../Data/287_rep_viruses/4251.clean.tsv
# ../Data/287_rep_viruses/10946.clean.tsv
# ../Data/287_rep_viruses/3028.clean.tsv
# ../Data/287_rep_viruses/3004.clean.tsv
# ../Data/287_rep_viruses/9768.clean.tsv
# ../Data/287_rep_viruses/9922.clean.tsv
# ../Data/287_rep_viruses/2567.clean.tsv
# ../Data/287_rep_viruses/10672.clean.tsv
# ../Data/287_rep_viruses/9511.clean.tsv
# ../Data/287_rep_viruses/7998.clean.tsv
# ../Data/287_rep_viruses/1429.clean.tsv
# ../Data/287_rep_viruses/7656.clean.tsv
# ../Data/287_rep_viruses/12970.clean.tsv
# ../Data/287_rep_viruses/12377.clean.tsv
# ../Data/287_rep_viruses/1408.clean.tsv
# ../Data/287_rep_viruses/4257.clean.tsv
# ../Data/287_rep_viruses/6342.clean.tsv
# ../Data/287_rep_viruses/9997.clean.tsv
# ../Data/287_rep_viruses/5605.clean.tsv
# ../Data/287_rep_viruses/7957.clean.tsv
# ../Data/287_rep_viruses/1606.clean.tsv
# ../Data/287_rep_viruses/8706.clean.tsv
# ../Data/287_rep_viruses/1411.clean.tsv
# ../Data/287_rep_viruses/3400.clean.tsv
# ../Data/287_rep_viruses/3366.clean.tsv
# ../Data/287_rep_viruses/10625.clean.tsv
# ../Data/287_rep_viruses/3700.clean.tsv
# ../Data/287_rep_viruses/4299.clean.tsv
# ../Data/287_rep_viruses/4066.clean.tsv
# ../Data/287_rep_viruses/9234.clean.tsv
# ../Data/287_rep_viruses/6643.clean.tsv
# ../Data/287_rep_viruses/3244.clean.tsv
# ../Data/287_rep_viruses/2418.clean.tsv
# ../Data/287_rep_viruses/9366.clean.tsv
# ../Data/287_rep_viruses/3609.clean.tsv
# ../Data/287_rep_viruses/7670.clean.tsv
# ../Data/287_rep_viruses/1395.clean.tsv
# ../Data/287_rep_viruses/6056.clean.tsv
# ../Data/287_rep_viruses/16352.clean.tsv
# ../Data/287_rep_viruses/19043.clean.tsv
# ../Data/287_rep_viruses/3555.clean.tsv
# ../Data/287_rep_viruses/4763.clean.tsv
# ../Data/287_rep_viruses/3469.clean.tsv
# ../Data/287_rep_viruses/8270.clean.tsv
# ../Data/287_rep_viruses/11113.clean.tsv
# ../Data/287_rep_viruses/1109.clean.tsv
# ../Data/287_rep_viruses/2616.clean.tsv
# ../Data/287_rep_viruses/9990.clean.tsv
# ../Data/287_rep_viruses/2997.clean.tsv
# ../Data/287_rep_viruses/2930.clean.tsv
# ../Data/287_rep_viruses/5930.clean.tsv
# ../Data/287_rep_viruses/1387.clean.tsv
# ../Data/287_rep_viruses/7705.clean.tsv
# ../Data/287_rep_viruses/3583.clean.tsv
# ../Data/287_rep_viruses/16139.clean.tsv
# ../Data/287_rep_viruses/2646.clean.tsv
# ../Data/287_rep_viruses/787.clean.tsv
# ../Data/287_rep_viruses/9892.clean.tsv
# ../Data/287_rep_viruses/2008.clean.tsv
# ../Data/287_rep_viruses/5839.clean.tsv
# ../Data/287_rep_viruses/16451.clean.tsv
# ../Data/287_rep_viruses/13110.clean.tsv
# ../Data/287_rep_viruses/9863.clean.tsv
# ../Data/287_rep_viruses/800.clean.tsv
# ../Data/287_rep_viruses/8463.clean.tsv
# ../Data/287_rep_viruses/1538.clean.tsv
# ../Data/287_rep_viruses/10418.clean.tsv
# ../Data/287_rep_viruses/6410.clean.tsv
# ../Data/287_rep_viruses/2763.clean.tsv

# %% [markdown]
# # Double checking sequence extraction

# %%
from Bio import SeqIO

# %%
taxa = 287
tsv_loc = '../Data/host_genomes/{}.clean.tsv'.format(taxa)
df = pd.read_csv(tsv_loc, sep = "\t", index_col = 0)

fasta_loc = '../Data/host_genomes/{}.fasta'.format(taxa)
genome_seq = SeqIO.read(fasta_loc, 'fasta')

gff3_loc = '../Data/host_genomes/{}.gff3'.format(taxa)
gff3_df = pd.read_csv(gff3_loc, sep='\t', comment='#', header=None)

# %%
seq_dicty = {}
gff3_df = gff3_df[gff3_df[2]=='CDS']

for index in gff3_df.index:
    if gff3_df.at[index, 6] == '+':
        start = gff3_df.at[index, 3]
        locus_tag = gff3_df.at[index, 8].split(';Parent=gene-')[1].split(';')[0]
        seq_dicty[locus_tag] = genome_seq.seq[start-31:start+29]
for index in df.index:
    if df.at[index, 'strand'] == '+':
        assert df.at[index, 'upstream_sequence']+df.at[index, 'coding_sequence'][:30] ==\
                seq_dicty[df.at[index, 'locus_tag']]

# %%
seq_dicty = {}
gff3_df = gff3_df[gff3_df[2]=='CDS']

for index in gff3_df.index:
    if gff3_df.at[index, 6] == '-':
        start = gff3_df.at[index, 4]
        locus_tag = gff3_df.at[index, 8].split(';Parent=gene-')[1].split(';')[0]
        seq_dicty[locus_tag] = genome_seq.seq[start-30:start+30].reverse_complement()
for index in df.index:
    if df.at[index, 'strand'] == '-':
        assert df.at[index, 'upstream_sequence']+df.at[index, 'coding_sequence'][:30] ==\
                seq_dicty[df.at[index, 'locus_tag']]

# %% [markdown]
# # And a little null analysis on the *expected* relationship between secondary structure and aSD binding energy

# %%
import json
import numpy as np

import statsmodels.formula.api as smf

# %%
gaps=(4,10)
RBS_len=6
with open('../Data/energy_files/energyRef_CCUCCU_ensemble_noneConstraint.json', 'r') as infile:
       energy_dict = json.load(infile)
        
ec_df = pd.read_csv('../Data/562_associated_data/ecoli.combined.tsv', sep='\t', index_col=0)
ec_df_indices = list(ec_df.index)

# %%
total_nts = ec_df['upstream_sequence'].str.len().sum()
for nt in ['A', 'T', 'G', 'C']:
    print(nt, ec_df['upstream_sequence'].str.count(nt).sum()/total_nts)
# Out:
# A 0.3184646962233169
# T 0.25085385878489325
# G 0.24104269293924466
# C 0.18963875205254516

# %% [markdown]
# **This takes a little while so I only am running once (thus commenting to prevent screwing it up) and saving the file and reading it back in later**

# %%
# ss_list = []
# rbs_list = []
# for i in range(200000):
# #     utr_str = ''.join(np.random.choice(['A', 'U', 'G', 'C'], p=[0.25, 0.25, 0.25, 0.25], size=30))
#     utr_str = ''.join(np.random.choice(['A', 'U', 'G', 'C'], p=[0.3185, 0.2509, 0.2410, 0.1896], size=30))
#     cds_seq = ec_df.iloc[np.random.choice(ec_df_indices)]['coding_sequence']
#     if len(cds_seq) > 30:
#         combined = utr_str + cds_seq[:30]
#         assert len(combined) == 60
#         rna_out = call_RNAfold(combined)
#         e1, e2 = get_energy_RNAfold(rna_out)
#         ss_list.append(e2)
        
#         ###Calculate the energy for the indicated gap offsets
#         energy_list = []
#         for gap in range(gaps[0],gaps[1]+1):
#              energy_list.append(energy_dict[utr_str[-gap - RBS_len: -gap]])

#         rbs_list.append(min(energy_list))
        
        
# random_df = pd.DataFrame(zip(ss_list, rbs_list), columns=['secondary_structure', 'RBS_energy'])
# print(random_df.shape)
# random_df.to_csv('../Data/562_associated_data/randomdata.tsv', sep='\t')

# %%
random_df = pd.read_csv('../Data/562_associated_data/randomdata.tsv', sep='\t', index_col=0)
print(random_df.shape)
random_df.head()
# Out:
# (200000, 2)
#    secondary_structure  RBS_energy
# 0               -13.36       -0.56
# 1               -15.99       -0.55
# 2               -12.12       -3.54
# 3                -4.07       -0.01
# 4               -10.99       -2.50

# %%
assert len(list(ec_df['genome_id'].value_counts().keys())) == 1
host_name = ec_df['genome_id'].value_counts().keys()[0]
#
concat_df = pd.concat((ec_df, random_df), ignore_index=True, sort=False)
concat_df['binary_predictor'] = 1
concat_df.at[concat_df[concat_df['genome_id'] == host_name].index, 'binary_predictor'] = 0
print(concat_df.shape)

concat_df['RBS_energy'] += 9.51
# Out:
# (204060, 26)

# %%
###Fixed intercept effect
fitted = smf.ols('secondary_structure ~ RBS_energy + I(binary_predictor)', data=concat_df).fit(disp=0)

###Random intercept 
# fitted = smf.mixedlm('secondary_structure ~ RBS_energy',\
#                  data=concat_df, groups=concat_df['binary_predictor']).fit(disp=0)

###Random slope
# fitted = smf.mixedlm('secondary_structure ~ RBS_energy',\
#                  data=concat_df, re_formula='0+RBS_energy', groups=concat_df['binary_predictor']).fit(disp=0)

###Random intercept and random slope
# fitted = smf.mixedlm('secondary_structure ~ RBS_energy',\
#                  data=concat_df, re_formula='RBS_energy', groups=concat_df['binary_predictor']).fit(disp=0)

print(fitted.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     secondary_structure   R-squared:                       0.028
# Model:                             OLS   Adj. R-squared:                  0.028
# Method:                  Least Squares   F-statistic:                     2908.
# Date:                 Tue, 10 Mar 2020   Prob (F-statistic):               0.00
# Time:                         12:30:35   Log-Likelihood:            -5.4169e+05
# No. Observations:               204060   AIC:                         1.083e+06
# Df Residuals:                   204057   BIC:                         1.083e+06
# Df Model:                            2
# Covariance Type:             nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept             -11.1982      0.057   -195.861      0.000     -11.310     -11.086
# RBS_energy              0.2981      0.004     75.217      0.000       0.290       0.306
# I(binary_predictor)    -1.5523      0.056    -27.847      0.000      -1.662      -1.443
# ==============================================================================
# Omnibus:                     9448.165   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11237.373
# Skew:                          -0.514   Prob(JB):                         0.00
# Kurtosis:                       3.514   Cond. No.                         80.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# **Parsimoniously grabbing similar values**

# %%
random_indices = []
for index in ec_df.index[:]:
    rbs = ec_df.loc[index]['RBS_energy']
    temp_df = random_df[random_df['RBS_energy'] == rbs]
    if temp_df.shape[0]>0:
        choice = np.random.choice(temp_df.index)
        random_indices.append(choice)

# %%
temp_df = random_df.loc[random_indices]
concat_df = pd.concat((ec_df, temp_df), ignore_index=True, sort=False)
concat_df['binary_predictor'] = 1
concat_df.at[concat_df[concat_df['genome_id'] == host_name].index, 'binary_predictor'] = 0
print(concat_df.shape)
# Out:
# (8120, 26)

# %%
fitted = smf.ols('secondary_structure ~ RBS_energy',\
                 data=ec_df).fit(disp=0)
print(fitted.summary())

fitted = smf.ols('secondary_structure ~ RBS_energy',\
                 data=temp_df).fit(disp=0)
print(fitted.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     secondary_structure   R-squared:                       0.072
# Model:                             OLS   Adj. R-squared:                  0.072
# Method:                  Least Squares   F-statistic:                     314.7
# Date:                 Tue, 10 Mar 2020   Prob (F-statistic):           7.04e-68
# Time:                         12:32:28   Log-Likelihood:                -10833.
# No. Observations:                 4060   AIC:                         2.167e+04
# Df Residuals:                     4058   BIC:                         2.168e+04
# Df Model:                            1
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -7.7048      0.129    -59.554      0.000      -7.958      -7.451
# RBS_energy     0.4363      0.025     17.740      0.000       0.388       0.485
# ==============================================================================
# Omnibus:                      719.577   Durbin-Watson:                   1.922
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1590.235
# Skew:                          -1.022   Prob(JB):                         0.00
# Kurtosis:                       5.285   Cond. No.                         12.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     secondary_structure   R-squared:                       0.009
# Model:                             OLS   Adj. R-squared:                  0.008
# Method:                  Least Squares   F-statistic:                     34.86
# Date:                 Tue, 10 Mar 2020   Prob (F-statistic):           3.83e-09
# Time:                         12:32:28   Log-Likelihood:                -10825.
# No. Observations:                 4060   AIC:                         2.165e+04
# Df Residuals:                     4058   BIC:                         2.167e+04
# Df Model:                            1
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -10.2323      0.129    -79.245      0.000     -10.485      -9.979
# RBS_energy     0.1449      0.025      5.904      0.000       0.097       0.193
# ==============================================================================
# Omnibus:                      139.996   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              155.065
# Skew:                          -0.455   Prob(JB):                     2.13e-34
# Kurtosis:                       3.298   Cond. No.                         12.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
temp_df['RBS_energy'].hist()

# %%
from scipy import stats
print(stats.spearmanr(rbs_list, ss_list), '\n\n', stats.linregress(rbs_list, ss_list))

# %%
stats.linregress(old['RBS_energy'], old['secondary_structure'])

# %%
print(old['secondary_structure'].mean(), np.mean(ss_list),\
      stats.ttest_ind(old['secondary_structure'], ss_list))
print()
print(old['RBS_energy'].mean(), np.mean(rbs_list),\
      stats.ttest_ind(old['RBS_energy'], rbs_list))

# %%
(0.3111*-9.51) + -9.91

# %%
(0.436*-9.51) + -7.7
