# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
df = pd.read_csv('../sequences (1).csv', sep=',')
print(df.shape)

df = df[df['Nuc_Completeness']=='complete']
print(df.shape)
# Out:
# (49602, 18)
# (17343, 18)

# %%
for i,j in dict(df['Host'].value_counts()).items():
    print(i, '\t\t', j)
# Out:
# Mycolicibacterium smegmatis MC2 155 		 1727
# Escherichia coli 		 744
# Gordonia terrae 		 382
# Escherichia coli C 		 346
# Lactococcus lactis 		 323
# Synechococcus 		 267
# Apis mellifera 		 265
# Mycolicibacterium smegmatis 		 251
# Klebsiella pneumoniae 		 245
# Pseudomonas aeruginosa 		 242
# Arthrobacter sp. ATCC 21022 		 231
# Salmonella enterica 		 217
# Staphylococcus aureus 		 209
# Microbacterium foliorum 		 208
# Streptococcus thermophilus 		 189
# Cutibacterium acnes 		 180
# Mycobacterium 		 139
# Pseudomonas aeruginosa PAO1 		 119
# Streptococcus pneumoniae 		 117
# Vibrio cholerae 		 108
# Acinetobacter baumannii 		 108
# Enterococcus faecalis 		 105
# Streptomyces griseus 		 97
# Salmonella sp. 		 79
# Escherichia 		 76
# Erwinia amylovora 		 75
# Campylobacter jejuni 		 72
# Enterobacterales 		 65
# Pseudomonas 		 63
# Paenibacillus larvae 		 63
# Escherichia coli O157:H7 		 62
# Bacillus cereus 		 59
# Listeria monocytogenes 		 58
# ...

# %%
df.columns
# Out:
# Index(['Accession', 'Release_Date', 'Species', 'Genus', 'Family', 'Length',
#        'Sequence_Type', 'Nuc_Completeness', 'Genotype', 'Segment', 'Authors',
#        'Publications', 'Geo_Location', 'Host', 'Isolation_Source',
#        'Collection_Date', 'BioSample', 'GenBank_Title'],
#       dtype='object')

# %%
df['Sequence_Type'].value_counts()
# Out:
# GenBank    14702
# RefSeq      2641
# Name: Sequence_Type, dtype: int64

# %%
df[df['Host'].str.contains('subtilis')==True]['Host'].value_counts()
# Out:
# Bacillus subtilis                             48
# Bacillus subtilis subsp. subtilis str. 168     2
# Bacillus subtilis subsp. natto                 2
# Name: Host, dtype: int64
